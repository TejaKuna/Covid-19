# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("/content/drive/MyDrive/covid data/Covid Data.csv")
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020       97          1
# 1      2             1    2             1  03-06-2020       97          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020       97          2
# 4      2             1    2             1  21-06-2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
#  14  OTHER_DISEASE         1048575 non-null  int64
#  15  CARDIOVASCULAR        1048575 non-null  int64
#  16  OBESITY               1048575 non-null  int64
#  17  RENAL_CHRONIC         1048575 non-null  int64
#  18  TOBACCO               1048575 non-null  int64
#  19  CLASIFFICATION_FINAL  1048575 non-null  int64
#  20  ICU                   1048575 non-null  int64
# dtypes: int64(20), object(1)
# memory usage: 168.0+ MB

# %%
df["DATE_DIED"].value_counts()
# Out:
# 9999-99-99    971633
# 06-07-2020      1000
# 07-07-2020       996
# 13-07-2020       990
# 16-06-2020       979
#                ...
# 24-11-2020         1
# 17-12-2020         1
# 08-12-2020         1
# 16-03-2021         1
# 22-04-2021         1
# Name: DATE_DIED, Length: 401, dtype: int64

# %%
#df['CLASIFFICATION_FINAL'].unique()

# %%
#df['MEDICAL_UNIT'].unique()

# %%
#df['PNEUMONIA'].unique()

# %%
#df['USMER'].unique()

# %%
#df['CARDIOVASCULAR'].value_counts()

# %%
#df['INTUBED'].value_counts()

# %%
#df['ICU'].value_counts()

# %%
#df['PNEUMONIA'].value_counts()

# %%
df['SEX']
# Out:
# 0          1
# 1          2
# 2          2
# 3          1
# 4          2
#           ..
# 1048570    2
# 1048571    2
# 1048572    2
# 1048573    2
# 1048574    2
# Name: SEX, Length: 1048575, dtype: int64

# %%
#these columns have very few missing values... so convert them into either 1 or 2.
df = df[(df.PNEUMONIA == 1) | (df.PNEUMONIA == 2)]
df = df[(df.DIABETES == 1) | (df.DIABETES == 2)]
df = df[(df.COPD == 1) | (df.COPD == 2)]
df = df[(df.ASTHMA == 1) | (df.ASTHMA == 2)]
df = df[(df.INMSUPR == 1) | (df.INMSUPR == 2)]
df = df[(df.HIPERTENSION == 1) | (df.HIPERTENSION == 2)]
df = df[(df.OTHER_DISEASE == 1) | (df.OTHER_DISEASE == 2)]
df = df[(df.CARDIOVASCULAR == 1) | (df.CARDIOVASCULAR == 2)]
df = df[(df.OBESITY == 1) | (df.OBESITY == 2)]
df = df[(df.RENAL_CHRONIC == 1) | (df.RENAL_CHRONIC == 2)]
df = df[(df.TOBACCO == 1) | (df.TOBACCO == 2)]

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020       97          1
# 1      2             1    2             1  03-06-2020       97          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020       97          2
# 4      2             1    2             1  21-06-2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %%
sns.countplot(x=df.SEX, hue = df.PREGNANT)
# Out:
# <Axes: xlabel='SEX', ylabel='count'>

# %%
plt.figure(figsize = (8,5))
d = sns.countplot(x=df.SEX, hue = df.PREGNANT)
for i in d.containers:
    d.bar_label(i)
plt.title("PREGNANCIES - SEX");

# %% [markdown]
# ### In pregnancies, 98 means null values for female and 97 means null values for males. We will convert 97 to 2 because men can't birth.

# %%
df.PREGNANT = df.PREGNANT.replace(98, 2)
df.PREGNANT = df.PREGNANT.replace(97, 2)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020       97          1
# 1      2             1    2             1  03-06-2020       97          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020       97          2
# 4      2             1    2             1  21-06-2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72         2         2  ...       2        2             1              2
# 2   55         2         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68         2         1  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
# 3               2        2              2        2                     7   97
# 4               2        2              2        2                     3   97
#
# [5 rows x 21 columns]

# %% [markdown]
# #### INTUBED , ICU Variables has so many null values. We delete it

# %%
df.drop("INTUBED", axis = 1, inplace = True)
df.drop("ICU", axis = 1, inplace = True)

# %%
df.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0      2             1    1             1  03-05-2020          1   65
# 1      2             1    2             1  03-06-2020          1   72
# 2      2             1    2             2  09-06-2020          2   55
# 3      2             1    1             1  12-06-2020          2   53
# 4      2             1    2             1  21-06-2020          2   68
#
#    PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2     2       2        2             1              2
# 1         2         2     2       2        2             1              2
# 2         2         1     2       2        2             2              2
# 3         2         2     2       2        2             2              2
# 4         2         1     2       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL
# 0               2        2              2        2                     3
# 1               2        1              1        2                     5
# 2               2        2              2        2                     3
# 3               2        2              2        2                     7
# 4               2        2              2        2                     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1025152 entries, 0 to 1048574
# Data columns (total 19 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1025152 non-null  int64
#  1   MEDICAL_UNIT          1025152 non-null  int64
#  2   SEX                   1025152 non-null  int64
#  3   PATIENT_TYPE          1025152 non-null  int64
#  4   DATE_DIED             1025152 non-null  object
#  5   PNEUMONIA             1025152 non-null  int64
#  6   AGE                   1025152 non-null  int64
#  7   PREGNANT              1025152 non-null  int64
#  8   DIABETES              1025152 non-null  int64
#  9   COPD                  1025152 non-null  int64
#  10  ASTHMA                1025152 non-null  int64
#  11  INMSUPR               1025152 non-null  int64
#  12  HIPERTENSION          1025152 non-null  int64
#  13  OTHER_DISEASE         1025152 non-null  int64
#  14  CARDIOVASCULAR        1025152 non-null  int64
#  15  OBESITY               1025152 non-null  int64
#  16  RENAL_CHRONIC         1025152 non-null  int64
#  17  TOBACCO               1025152 non-null  int64
#  18  CLASIFFICATION_FINAL  1025152 non-null  int64
# dtypes: int64(18), object(1)
# memory usage: 156.4+ MB

# %%
df.CLASIFFICATION_FINAL.value_counts()
# Out:
# 7    490123
# 3    378629
# 6    117756
# 5     25305
# 1      8448
# 4      3090
# 2      1801
# Name: CLASIFFICATION_FINAL, dtype: int64

# %% [markdown]
# ### 1-2-3 means COVID and 4-5-6-7 means not COVID. So we convert like that.

# %%
df.CLASIFFICATION_FINAL = df.CLASIFFICATION_FINAL.replace([1,2,3], 1)
df.CLASIFFICATION_FINAL = df.CLASIFFICATION_FINAL.replace([4,5,6,7], 2)

# %%
df.CLASIFFICATION_FINAL.value_counts()
# Out:
# 2    636274
# 1    388878
# Name: CLASIFFICATION_FINAL, dtype: int64

# %%
plt.figure(figsize = (3,5))
d = sns.countplot(x=df.CLASIFFICATION_FINAL)
for i in d.containers:
    d.bar_label(i)
plt.title(" COVID AND NON-COVID");

# %% [markdown]
# #### We will make a variable that shows us die date. So if we do anything with these dates, it means they are dead numbers.

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0            2             1    1             1  03-05-2020          1   65
# 1            2             1    2             1  03-06-2020          1   72
# 2            2             1    2             2  09-06-2020          2   55
# 3            2             1    1             1  12-06-2020          2   53
# 4            2             1    2             1  21-06-2020          2   68
# ...        ...           ...  ...           ...         ...        ...  ...
# 1048570      2            13    2             1  9999-99-99          2   40
# 1048571      1            13    2             2  9999-99-99          2   51
# 1048572      2            13    2             1  9999-99-99          2   55
# 1048573      2            13    2             1  9999-99-99          2   28
# 1048574      2            13    2             1  9999-99-99          2   52
#
#          PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  \
# 0               2         2     2       2        2             1
# 1               2         2     2       2        2             1
# 2               2         1     2       2        2             2
# 3               2         2     2       2        2             2
# 4               2         1     2       2        2             1
# ...           ...       ...   ...     ...      ...           ...
# 1048570         2         2     2       2        2             2
# 1048571         2         2     2       2        2             1
# 1048572         2         2     2       2        2             2
# 1048573         2         2     2       2        2             2
# 1048574         2         2     2       2        2             2
#
#          OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0                    2               2        2              2        2
# 1                    2               2        1              1        2
# 2                    2               2        2              2        2
# 3                    2               2        2              2        2
# 4                    2               2        2              2        2
# ...                ...             ...      ...            ...      ...
# 1048570              2               2        2              2        2
# 1048571              2               2        2              2        2
# 1048572              2               2        2              2        2
# 1048573              2               2        2              2        2
# 1048574              2               2        2              2        2
#
#          CLASIFFICATION_FINAL
# 0                           1
# 1                           2
# 2                           1
# 3                           2
# 4                           1
# ...                       ...
# 1048570                     2
# 1048571                     2
# 1048572                     2
# 1048573                     2
# 1048574                     2
#
# [1025152 rows x 19 columns]

# %%
df["MONTH"] = df.DATE_DIED.str.split("-", expand = True)[1]
df["YEAR"] = df.DATE_DIED.str.split("-", expand = True)[2]

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0            2             1    1             1  03-05-2020          1   65
# 1            2             1    2             1  03-06-2020          1   72
# 2            2             1    2             2  09-06-2020          2   55
# 3            2             1    1             1  12-06-2020          2   53
# 4            2             1    2             1  21-06-2020          2   68
# ...        ...           ...  ...           ...         ...        ...  ...
# 1048570      2            13    2             1  9999-99-99          2   40
# 1048571      1            13    2             2  9999-99-99          2   51
# 1048572      2            13    2             1  9999-99-99          2   55
# 1048573      2            13    2             1  9999-99-99          2   28
# 1048574      2            13    2             1  9999-99-99          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0               2         2     2  ...        2             1              2
# 1               2         2     2  ...        2             1              2
# 2               2         1     2  ...        2             2              2
# 3               2         2     2  ...        2             2              2
# 4               2         1     2  ...        2             1              2
# ...           ...       ...   ...  ...      ...           ...            ...
# 1048570         2         2     2  ...        2             2              2
# 1048571         2         2     2  ...        2             1              2
# 1048572         2         2     2  ...        2             2              2
# 1048573         2         2     2  ...        2             2              2
# 1048574         2         2     2  ...        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0                     2        2              2        2
# 1                     2        1              1        2
# 2                     2        2              2        2
# 3                     2        2              2        2
# 4                     2        2              2        2
# ...                 ...      ...            ...      ...
# 1048570               2        2              2        2
# 1048571               2        2              2        2
# 1048572               2        2              2        2
# 1048573               2        2              2        2
# 1048574               2        2              2        2
#
#          CLASIFFICATION_FINAL  MONTH  YEAR
# 0                           1     05  2020
# 1                           2     06  2020
# 2                           1     06  2020
# 3                           2     06  2020
# 4                           1     06  2020
# ...                       ...    ...   ...
# 1048570                     2     99    99
# 1048571                     2     99    99
# 1048572                     2     99    99
# 1048573                     2     99    99
# 1048574                     2     99    99
#
# [1025152 rows x 21 columns]

# %%
df.YEAR.value_counts()
# Out:
# 99      950438
# 2020     74402
# 2021       312
# Name: YEAR, dtype: int64

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0            2             1    1             1  03-05-2020          1   65
# 1            2             1    2             1  03-06-2020          1   72
# 2            2             1    2             2  09-06-2020          2   55
# 3            2             1    1             1  12-06-2020          2   53
# 4            2             1    2             1  21-06-2020          2   68
# ...        ...           ...  ...           ...         ...        ...  ...
# 1048570      2            13    2             1  9999-99-99          2   40
# 1048571      1            13    2             2  9999-99-99          2   51
# 1048572      2            13    2             1  9999-99-99          2   55
# 1048573      2            13    2             1  9999-99-99          2   28
# 1048574      2            13    2             1  9999-99-99          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0               2         2     2  ...        2             1              2
# 1               2         2     2  ...        2             1              2
# 2               2         1     2  ...        2             2              2
# 3               2         2     2  ...        2             2              2
# 4               2         1     2  ...        2             1              2
# ...           ...       ...   ...  ...      ...           ...            ...
# 1048570         2         2     2  ...        2             2              2
# 1048571         2         2     2  ...        2             1              2
# 1048572         2         2     2  ...        2             2              2
# 1048573         2         2     2  ...        2             2              2
# 1048574         2         2     2  ...        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0                     2        2              2        2
# 1                     2        1              1        2
# 2                     2        2              2        2
# 3                     2        2              2        2
# 4                     2        2              2        2
# ...                 ...      ...            ...      ...
# 1048570               2        2              2        2
# 1048571               2        2              2        2
# 1048572               2        2              2        2
# 1048573               2        2              2        2
# 1048574               2        2              2        2
#
#          CLASIFFICATION_FINAL  MONTH  YEAR
# 0                           1     05  2020
# 1                           2     06  2020
# 2                           1     06  2020
# 3                           2     06  2020
# 4                           1     06  2020
# ...                       ...    ...   ...
# 1048570                     2     99    99
# 1048571                     2     99    99
# 1048572                     2     99    99
# 1048573                     2     99    99
# 1048574                     2     99    99
#
# [1025152 rows x 21 columns]

# %%
y1=df[(df['YEAR']=='2020' ) | (df['YEAR']=='2021' )]
y1['YEAR'].value_counts()
# Out:
# 2020    74402
# 2021      312
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize = (6,5))
d = sns.countplot(x = "YEAR", hue = "PATIENT_TYPE", data = y1)
plt.title("COVID DEATHS BY YEAR", fontsize = 16)
for i in d.containers:
    d.bar_label(i)

# %%
plt.figure(figsize = (8,8))
d = sns.countplot(x = "MONTH", hue = "PATIENT_TYPE", data = y1)
plt.title("COVID DEATHS BY MONTH", fontsize = 16)
for i in d.containers:
    d.bar_label(i)

# %%
plt.figure(figsize = (8,8))
d = sns.countplot(x =y1['MONTH'].sort_values(ascending=True), hue = "PATIENT_TYPE", data = y1)
plt.title("COVID DEATHS BY MONTH", fontsize = 16)
for i in d.containers:
    d.bar_label(i)

# %%
plt.figure(figsize = (8,8))
#d = sns.countplot(x =y1['MONTH'].sort_values(ascending=True), hue = "PATIENT_TYPE", data = y1)
d1 = sns.countplot(x =y1['YEAR'].sort_values(ascending=True), hue = "PATIENT_TYPE", data = y1)
plt.title("COVID DEATHS BY MONTH", fontsize = 16)
for i in d1.containers:
    d1.bar_label(i)

# %%
y2=df[(df['YEAR']=='2020')]
y2['YEAR'].value_counts()
# Out:
# 2020    74402
# Name: YEAR, dtype: int64

# %%
y2.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0      2             1    1             1  03-05-2020          1   65
# 1      2             1    2             1  03-06-2020          1   72
# 2      2             1    2             2  09-06-2020          2   55
# 3      2             1    1             1  12-06-2020          2   53
# 4      2             1    2             1  21-06-2020          2   68
#
#    PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2     2  ...        2             1              2
# 1         2         2     2  ...        2             1              2
# 2         2         1     2  ...        2             2              2
# 3         2         2     2  ...        2             2              2
# 4         2         1     2  ...        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  \
# 0               2        2              2        2                     1
# 1               2        1              1        2                     2
# 2               2        2              2        2                     1
# 3               2        2              2        2                     2
# 4               2        2              2        2                     1
#
#    MONTH  YEAR
# 0     05  2020
# 1     06  2020
# 2     06  2020
# 3     06  2020
# 4     06  2020
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize = (8,8))
d = sns.countplot(x = y2["MONTH"].sort_values(ascending=True), hue = "PATIENT_TYPE", data = y2)
plt.title("COVID DEATHS BY MONTH", fontsize = 16)
for i in d.containers:
    d.bar_label(i)

# %%
y3=df[(df['YEAR']=='2021')]
y3['YEAR'].value_counts()
# Out:
# 2021    312
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize = (8,8))
d = sns.countplot(x = y3["MONTH"].sort_values(ascending=True), hue = "PATIENT_TYPE", data = y3)
plt.title("COVID DEATHS BY MONTH", fontsize = 16)
for i in d.containers:
    d.bar_label(i)

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  PNEUMONIA  AGE  \
# 0            2             1    1             1  03-05-2020          1   65
# 1            2             1    2             1  03-06-2020          1   72
# 2            2             1    2             2  09-06-2020          2   55
# 3            2             1    1             1  12-06-2020          2   53
# 4            2             1    2             1  21-06-2020          2   68
# ...        ...           ...  ...           ...         ...        ...  ...
# 1048570      2            13    2             1  9999-99-99          2   40
# 1048571      1            13    2             2  9999-99-99          2   51
# 1048572      2            13    2             1  9999-99-99          2   55
# 1048573      2            13    2             1  9999-99-99          2   28
# 1048574      2            13    2             1  9999-99-99          2   52
#
#          PREGNANT  DIABETES  COPD  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0               2         2     2  ...        2             1              2
# 1               2         2     2  ...        2             1              2
# 2               2         1     2  ...        2             2              2
# 3               2         2     2  ...        2             2              2
# 4               2         1     2  ...        2             1              2
# ...           ...       ...   ...  ...      ...           ...            ...
# 1048570         2         2     2  ...        2             2              2
# 1048571         2         2     2  ...        2             1              2
# 1048572         2         2     2  ...        2             2              2
# 1048573         2         2     2  ...        2             2              2
# 1048574         2         2     2  ...        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  \
# 0                     2        2              2        2
# 1                     2        1              1        2
# 2                     2        2              2        2
# 3                     2        2              2        2
# 4                     2        2              2        2
# ...                 ...      ...            ...      ...
# 1048570               2        2              2        2
# 1048571               2        2              2        2
# 1048572               2        2              2        2
# 1048573               2        2              2        2
# 1048574               2        2              2        2
#
#          CLASIFFICATION_FINAL  MONTH  YEAR
# 0                           1     05  2020
# 1                           2     06  2020
# 2                           1     06  2020
# 3                           2     06  2020
# 4                           1     06  2020
# ...                       ...    ...   ...
# 1048570                     2     99    99
# 1048571                     2     99    99
# 1048572                     2     99    99
# 1048573                     2     99    99
# 1048574                     2     99    99
#
# [1025152 rows x 21 columns]

# %%
df.drop(["DATE_DIED", "MONTH", "YEAR"], axis = 1, inplace = True)

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA  AGE  PREGNANT  \
# 0            2             1    1             1          1   65         2
# 1            2             1    2             1          1   72         2
# 2            2             1    2             2          2   55         2
# 3            2             1    1             1          2   53         2
# 4            2             1    2             1          2   68         2
# ...        ...           ...  ...           ...        ...  ...       ...
# 1048570      2            13    2             1          2   40         2
# 1048571      1            13    2             2          2   51         2
# 1048572      2            13    2             1          2   55         2
# 1048573      2            13    2             1          2   28         2
# 1048574      2            13    2             1          2   52         2
#
#          DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0               2     2       2        2             1              2
# 1               2     2       2        2             1              2
# 2               1     2       2        2             2              2
# 3               2     2       2        2             2              2
# 4               1     2       2        2             1              2
# ...           ...   ...     ...      ...           ...            ...
# 1048570         2     2       2        2             2              2
# 1048571         2     2       2        2             1              2
# 1048572         2     2       2        2             2              2
# 1048573         2     2       2        2             2              2
# 1048574         2     2       2        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL
# 0                     2        2              2        2                     1
# 1                     2        1              1        2                     2
# 2                     2        2              2        2                     1
# 3                     2        2              2        2                     2
# 4                     2        2              2        2                     1
# ...                 ...      ...            ...      ...                   ...
# 1048570               2        2              2        2                     2
# 1048571               2        2              2        2                     2
# 1048572               2        2              2        2                     2
# 1048573               2        2              2        2                     2
# 1048574               2        2              2        2                     2
#
# [1025152 rows x 18 columns]

# %%
df["CLASIFFICATION_FINAL"] = df["CLASIFFICATION_FINAL"] - 1
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  PNEUMONIA  AGE  PREGNANT  \
# 0            2             1    1             1          1   65         2
# 1            2             1    2             1          1   72         2
# 2            2             1    2             2          2   55         2
# 3            2             1    1             1          2   53         2
# 4            2             1    2             1          2   68         2
# ...        ...           ...  ...           ...        ...  ...       ...
# 1048570      2            13    2             1          2   40         2
# 1048571      1            13    2             2          2   51         2
# 1048572      2            13    2             1          2   55         2
# 1048573      2            13    2             1          2   28         2
# 1048574      2            13    2             1          2   52         2
#
#          DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0               2     2       2        2             1              2
# 1               2     2       2        2             1              2
# 2               1     2       2        2             2              2
# 3               2     2       2        2             2              2
# 4               1     2       2        2             1              2
# ...           ...   ...     ...      ...           ...            ...
# 1048570         2     2       2        2             2              2
# 1048571         2     2       2        2             1              2
# 1048572         2     2       2        2             2              2
# 1048573         2     2       2        2             2              2
# 1048574         2     2       2        2             2              2
#
#          CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL
# 0                     2        2              2        2                     0
# 1                     2        1              1        2                     1
# 2                     2        2              2        2                     0
# 3                     2        2              2        2                     1
# 4                     2        2              2        2                     0
# ...                 ...      ...            ...      ...                   ...
# 1048570               2        2              2        2                     1
# 1048571               2        2              2        2                     1
# 1048572               2        2              2        2                     1
# 1048573               2        2              2        2                     1
# 1048574               2        2              2        2                     1
#
# [1025152 rows x 18 columns]

# %% [markdown]
# ### Modelling

# %%
X = df.drop("CLASIFFICATION_FINAL", axis = 1)
y = df["CLASIFFICATION_FINAL"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ### 3.XG boost (default parameters)

# %%
from xgboost import XGBClassifier
xgb_model=XGBClassifier()
xgb_model.fit(X_train,y_train)

#Prediction
ypred_train=xgb_model.predict(X_train)
ypred_test=xgb_model.predict(X_test)

#Evaluation
#1.Train & test accuracy
from sklearn.metrics import accuracy_score
print("Train accuracy",accuracy_score(y_train,ypred_train))
print("Test accuracy",accuracy_score(y_test,ypred_test))

#2.Cross Validation Score
from sklearn.model_selection import cross_val_score
scores=cross_val_score(xgb_model,X=X,y=y,cv=5)
print("cross validation score:",scores.mean())
# Out:
# Train accuracy 0.6680810918526322
# Test accuracy 0.6657930846117329
# cross validation score: 0.6032540815106345

# %% [markdown]
# ####   Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

estimator=XGBClassifier()

param_grid={'n_estimators':[10,20,40,50],
            'max_depth':[4,5,6],
            'gamma':[0,0.3,0.5,1]}

grid=GridSearchCV(xgb_model,param_grid,cv=5,scoring='accuracy')
grid.fit(X_train,y_train)
grid.best_params_
# Out:
# {'gamma': 0.3, 'max_depth': 6, 'n_estimators': 40}

# %% [markdown]
# ### Feature imp

# %%
grid.best_estimator_.feature_importances_
# Out:
# array([0.01036871, 0.02151524, 0.02127696, 0.15165873, 0.578502  ,
#        0.03615364, 0.00541191, 0.01425924, 0.02090892, 0.00686437,
#        0.01774395, 0.00726001, 0.01242213, 0.01403432, 0.03615865,
#        0.0175145 , 0.02794681], dtype=float32)

# %%
feats=pd.DataFrame(index=X.columns,
                   data=grid.best_estimator_.feature_importances_,
                  columns=['Importance'])

imp_features_list=feats[feats['Importance']>0.02].index.to_list()
imp_features_list
# Out:
# ['MEDICAL_UNIT',
#  'SEX',
#  'PATIENT_TYPE',
#  'PNEUMONIA',
#  'AGE',
#  'COPD',
#  'OBESITY',
#  'TOBACCO']

# %%
X_imp=X[imp_features_list]    #dropped unimp features

X_train,X_test,y_train,y_test= train_test_split(X_imp,y,test_size=0.3,random_state=42)

xgb_bhp=XGBClassifier(gamma=0.3,max_depth=6,n_estimators=40)
xgb_bhp.fit(X_train,y_train)

ypred_train=xgb_bhp.predict(X_train)
predictions=xgb_bhp.predict(X_test)

from sklearn.metrics import accuracy_score
print("Train_accuracy:",accuracy_score(y_train,ypred_train))
print("Test_accuracy:",accuracy_score(y_test,predictions))

scores=cross_val_score(xgb_bhp,X,y,cv=5)
print("Cross validation score:", scores.mean())
# Out:
# Train_accuracy: 0.6643798964891597
# Test_accuracy: 0.6646973135726038
# Cross validation score: 0.6042783180120029
